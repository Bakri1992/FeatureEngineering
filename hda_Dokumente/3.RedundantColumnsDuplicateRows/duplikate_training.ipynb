# %%
import pandas as pd 
import numpy as np
from recordlinkage.preprocessing import clean
from recordlinkage.preprocessing import phonetic
from recordlinkage.preprocessing import phonenumbers
import re

# %%
df=pd.read_csv("names_adress.csv")

# %%
df.head()
# Out:
#                name     phone_number       occupation  \
# 0   1. Rachel Green   1(613)555 0149  buyer (fashion)
# 1    2. Ross Geller  +1-613-555-0138     paleontogist
# 2  3. Mönica Geller      16135550185             Chef
# 3  4. Chandler BING   1 613 555 0161              ???
# 4  5. Pheobe Buffay    1(613)5550114         musician
#
#                           address
# 0       90 Bedford Street, Apt 20
# 1  100 Grove Street, Apartment 16
# 2       90 Bedford Street, Apt 20
# 3       90 Bedford Street, Apt 19
# 4        5 Morton Street, Apt. 14

# %%
df["name"]=clean(df["name"])
df["occupation"]=clean(df["occupation"])
df["phone_number"]=phonenumbers(df["phone_number"])

# %%
df[["street","house_no"]]=df["address"].str.split(",",expand=True)
df.drop(columns="address",inplace=True)

# %%
# Lets replace the empty cell with NaN
df.replace("",np.NaN,inplace=True)

# %%
# Lets clean the name using regular expression:
df["name"]=df["name"].apply(lambda x: re.sub(r"\d\s","",x))

# %%
df[["first_name","surname"]]=df["name"].str.split(" ",expand=True)
df.drop(columns="name",inplace=True)

# %%
df
# Out:
#    phone_number    occupation             street       house_no first_name  \
# 0   16135550149         buyer  90 Bedford Street         Apt 20     rachel
# 1  +16135550138  paleontogist   100 Grove Street   Apartment 16       ross
# 2   16135550185          chef  90 Bedford Street         Apt 20      mnica
# 3   16135550161           NaN  90 Bedford Street         Apt 19   chandler
# 4   16135550114      musician    5 Morton Street        Apt. 14     pheobe
# 5   16135550148         actor  90 Bedford Street         Apt 19     joseph
#
#      surname
# 0      green
# 1     geller
# 2     geller
# 3       bing
# 4     buffay
# 5  tribbiani

# %%
df["phonetische_kodierung"]=phonetic(df["surname"],"soundex")

# %%
df
# Out:
#    phone_number    occupation             street       house_no first_name  \
# 0   16135550149         buyer  90 Bedford Street         Apt 20     rachel
# 1  +16135550138  paleontogist   100 Grove Street   Apartment 16       ross
# 2   16135550185          chef  90 Bedford Street         Apt 20      mnica
# 3   16135550161           NaN  90 Bedford Street         Apt 19   chandler
# 4   16135550114      musician    5 Morton Street        Apt. 14     pheobe
# 5   16135550148         actor  90 Bedford Street         Apt 19     joseph
#
#      surname phonetische_kodierung
# 0      green                  G650
# 1     geller                  G460
# 2     geller                  G460
# 3       bing                  B520
# 4     buffay                  B100
# 5  tribbiani                  T615

# %% [markdown]
# ##### ``Indexing:``

# %%
from recordlinkage import index,datasets,compare
from recordlinkage.preprocessing import phonetic

# %%
df=datasets.load_febrl1()

# %%
print(df.shape)
df.head()
# Out:
# (1000, 10)
#              given_name     surname street_number          address_1  \
# rec_id
# rec-223-org         NaN      waller             6   tullaroop street
# rec-122-org     lachlan       berry            69      giblin street
# rec-373-org      deakin  sondergeld            48  goldfinch circuit
# rec-10-dup-0      kayla  harrington           NaN     maltby circuit
# rec-227-org        luke      purdon            23       ramsay place
#
#               address_2      suburb postcode state date_of_birth soc_sec_id
# rec_id
# rec-223-org    willaroo    st james     4011    wa      19081209    6988048
# rec-122-org   killarney     bittern     4814   qld      19990219    7364009
# rec-373-org     kooltuo  canterbury     2776   vic      19600210    2635962
# rec-10-dup-0    coaling    coolaroo     3465   nsw      19150612    9004242
# rec-227-org      mirani     garbutt     2260   vic      19831024    8099933

# %%
df["phonetic_surname"]=phonetic(df["surname"],"soundex",concat=True)
df.head()
# Out:
#              given_name     surname street_number          address_1  \
# rec_id
# rec-223-org         NaN      waller             6   tullaroop street
# rec-122-org     lachlan       berry            69      giblin street
# rec-373-org      deakin  sondergeld            48  goldfinch circuit
# rec-10-dup-0      kayla  harrington           NaN     maltby circuit
# rec-227-org        luke      purdon            23       ramsay place
#
#               address_2      suburb postcode state date_of_birth soc_sec_id  \
# rec_id
# rec-223-org    willaroo    st james     4011    wa      19081209    6988048
# rec-122-org   killarney     bittern     4814   qld      19990219    7364009
# rec-373-org     kooltuo  canterbury     2776   vic      19600210    2635962
# rec-10-dup-0    coaling    coolaroo     3465   nsw      19150612    9004242
# rec-227-org      mirani     garbutt     2260   vic      19831024    8099933
#
#              phonetic_surname
# rec_id
# rec-223-org              W460
# rec-122-org              B600
# rec-373-org              S536
# rec-10-dup-0             H652
# rec-227-org              P635

# %%
# This will make me indices where the similarity of the surname are cause I did phonetic on it
indexer=index.Block("phonetic_surname")
canditat=indexer.index(df)
canditat
# Out:
# MultiIndex([('rec-264-dup-0',   'rec-223-org'),
#             (  'rec-264-org',   'rec-223-org'),
#             (  'rec-264-org', 'rec-264-dup-0'),
#             (  'rec-419-org',   'rec-122-org'),
#             (  'rec-276-org',   'rec-122-org'),
#             (  'rec-276-org',   'rec-419-org'),
#             ('rec-276-dup-0',   'rec-122-org'),
#             ('rec-276-dup-0',   'rec-419-org'),
#             ('rec-276-dup-0',   'rec-276-org'),
#             ( 'rec-40-dup-0',   'rec-122-org'),
#             ...
#             ( 'rec-87-dup-0',    'rec-87-org'),
#             (  'rec-104-org', 'rec-104-dup-0'),
#             ('rec-310-dup-0',   'rec-310-org'),
#             ('rec-298-dup-0',   'rec-298-org'),
#             ('rec-345-dup-0',   'rec-345-org'),
#             ( 'rec-16-dup-0',    'rec-16-org'),
#             (  'rec-318-org', 'rec-318-dup-0'),
#             (  'rec-236-org', 'rec-236-dup-0'),
#             ('rec-299-dup-0',   'rec-299-org'),
#             (  'rec-132-org', 'rec-132-dup-0')],
#            names=['rec_id_1', 'rec_id_2'], length=2368)
