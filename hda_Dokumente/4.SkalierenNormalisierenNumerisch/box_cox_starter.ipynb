# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np
from scipy.stats import boxcox

# %% [markdown]
# Daten laden

# %%
df = pd.read_csv('../Data/housing.csv')

# %%
df.total_rooms.describe()
# Out:
# count    20640.000000
# mean      2635.763081
# std       2181.615252
# min          2.000000
# 25%       1447.750000
# 50%       2127.000000
# 75%       3148.000000
# max      39320.000000
# Name: total_rooms, dtype: float64

# %%
df.total_rooms.hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# Box Cox mit automatischer Parameterwahl
